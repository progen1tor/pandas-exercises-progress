# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import re

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
chipo = chipo.drop_duplicates(subset=['item_name', 'choice_description'])

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.item_price = chipo.item_price.apply(lambda pr: re.search(r'\d+\.?\d*', pr).group()).astype('float64')
chipo['product_price'] = chipo.item_price / chipo.quantity
flt = chipo.loc[chipo.product_price > 10]
flt.shape[0]
# Out:
# 707

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
flt[['item_name', 'choice_description', 'product_price']]
# Out:
#             item_name                                 choice_description  \
# 5        Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7       Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 13       Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 23    Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# 39      Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# ...               ...                                                ...
# 4593    Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...
# 4594    Barbacoa Bowl  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...
# 4607    Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 4610    Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4611   Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
#
#       product_price
# 5             10.98
# 7             11.75
# 13            11.25
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values('item_name')
# Out:
#       order_id  quantity          item_name  \
# 341        148         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 357        154         1  6 Pack Soft Drink
# 721        298         1  6 Pack Soft Drink
# 3141      1253         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 738        304         1  Veggie Soft Tacos
# 3889      1559         2  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 341                                         [Diet Coke]        6.49
# 298                                            [Sprite]        6.49
# 357                                              [Coke]        6.49
# 721                                            [Nestea]        6.49
# 3141                                         [Lemonade]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.iloc[chipo.item_price.idxmax()].quantity
# Out:
# np.int64(1)

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo.loc[chipo.item_name == 'Veggie Salad Bowl'].quantity.sum()
# Out:
# np.int64(16)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo.loc[(chipo.item_name == 'Canned Soda') & (chipo.quantity > 1)].shape[0]
# Out:
# 3
